# %%
## 0.Setup

# %%
### Installation

# %%
# !pip install langchain langchain-text-splitters langchain-community bs4
# Out:
# Requirement already satisfied: langchain in c:\users\admin\anaconda3\lib\site-packages (1.0.8)
# Requirement already satisfied: langchain-text-splitters in c:\users\admin\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: langchain-community in c:\users\admin\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: bs4 in c:\users\admin\anaconda3\lib\site-packages (0.0.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.6 in c:\users\admin\anaconda3\lib\site-packages (from langchain) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\admin\anaconda3\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\admin\anaconda3\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (0.4.46)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\admin\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\anaconda3\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\admin\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (24.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain) (4.14.1)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\admin\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\admin\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\admin\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\admin\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.27.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.7.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\admin\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: anyio in c:\users\admin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\admin\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\admin\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\admin\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain) (2.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\admin\anaconda3\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\admin\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)

# %%
### LangSmith

# %%
import getpass
import os

os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_API_KEY"] = getpass.getpass()
# Out:
#  ········

# %%
### Components

# %%
# !pip install -U "langchain[google-genai]"
# Out:
# Requirement already satisfied: langchain[google-genai] in c:\users\admin\anaconda3\lib\site-packages (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.6 in c:\users\admin\anaconda3\lib\site-packages (from langchain[google-genai]) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\admin\anaconda3\lib\site-packages (from langchain[google-genai]) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\admin\anaconda3\lib\site-packages (from langchain[google-genai]) (2.8.2)
# Requirement already satisfied: langchain-google-genai in c:\users\admin\anaconda3\lib\site-packages (from langchain[google-genai]) (3.1.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (0.4.46)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (4.14.1)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\admin\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\admin\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\admin\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\admin\anaconda3\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.6.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\admin\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (2.20.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-google-genai->langchain[google-genai]) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.9.0 in c:\users\admin\anaconda3\lib\site-packages (from langchain-google-genai->langchain[google-genai]) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\admin\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\admin\anaconda3\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\admin\anaconda3\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\admin\anaconda3\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\admin\anaconda3\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (6.33.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\admin\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (2.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\admin\anaconda3\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\admin\anaconda3\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (0.27.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\admin\anaconda3\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\admin\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (0.23.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\admin\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.72.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\admin\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (4.9.1)
# Requirement already satisfied: anyio in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (4.2.0)
# Requirement already satisfied: certifi in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.0.2)
# Requirement already satisfied: idna in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.7)
# Requirement already satisfied: sniffio in c:\users\admin\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\admin\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (0.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (2.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\admin\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (0.4.8)

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = "AIzaSyDzlkw7zuW6uwZPIh9o_H7VCJRTMwoaLrA"

model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
# !pip install -qU langchain-google-genai

# %%
import getpass
import os

if not os.environ.get("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter API key for Google Gemini: ")

from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

# %%
# !pip install -U "langchain-core"

# %%
from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore(embeddings)

# %%
## 1. Indexing

# %%
### Loading documents

# %%
import bs4
from langchain_community.document_loaders import WebBaseLoader

# Only keep post title, headers, and content from the full HTML.
bs4_strainer = bs4.SoupStrainer(class_=("post-title", "post-header", "post-content"))
loader = WebBaseLoader(
    web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),
    bs_kwargs={"parse_only": bs4_strainer},
)
docs = loader.load()

assert len(docs) == 1
print(f"Total characters: {len(docs[0].page_content)}")
# Out:
# Total characters: 43047

# %%
print(docs[0].page_content[:500])
# Out:
#       LLM Powered Autonomous Agents
#
# Date: June 23, 2023  |  Estimated Reading Time: 31 min  |  Author: Lilian Weng
#
#
# Building agents with LLM (large language model) as its core controller is a cool concept. Several proof-of-concepts demos, such as AutoGPT, GPT-Engineer and BabyAGI, serve as inspiring examples. The potentiality of LLM extends beyond generating well-written copies, stories, essays and programs; it can be framed as a powerful general problem solver.
# Agent System Overview#
# In

# %%
### Splitting documents

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,  # chunk size (characters)
    chunk_overlap=200,  # chunk overlap (characters)
    add_start_index=True,  # track index in original document
)
all_splits = text_splitter.split_documents(docs)

print(f"Split blog post into {len(all_splits)} sub-documents.")
# Out:
# Split blog post into 63 sub-documents.

# %%
### Storing documents

# %%
document_ids = vector_store.add_documents(documents=all_splits)

print(document_ids[:3])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 document_ids = vector_store.add_documents(documents=all_splits)
#       3 print(document_ids[:3])
#
# File ~\anaconda3\Lib\site-packages\langchain_core\vectorstores\in_memory.py:194, in InMemoryVectorStore.add_documents(self, documents, ids, **kwargs)
#     186 @override
#     187 def add_documents(
#     188     self,
#    (...)
#     191     **kwargs: Any,
#     192 ) -> list[str]:
#     193     texts = [doc.page_content for doc in documents]
# --> 194     vectors = self.embedding.embed_documents(texts)
#     196     if ids and len(ids) != len(texts):
#     197         msg = (
#     198             f"ids must be the same length as texts. "
#     199             f"Got {len(ids)} ids and {len(texts)} texts."
#     200         )
#
# File ~\anaconda3\Lib\site-packages\langchain_openai\embeddings\base.py:702, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     699 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     700 # This could be optimized to avoid double work when all texts are short enough.
#     701 engine = cast(str, self.deployment)
# --> 702 return self._get_len_safe_embeddings(
#     703     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     704 )
#
# File ~\anaconda3\Lib\site-packages\langchain_openai\embeddings\base.py:569, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     567 # Make API call with this batch
#     568 batch_tokens = tokens[i:batch_end]
# --> 569 response = self.client.create(input=batch_tokens, **client_kwargs)
#     570 if not isinstance(response, dict):
#     571     response = response.model_dump()
#
# File ~\anaconda3\Lib\site-packages\openai\resources\embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
